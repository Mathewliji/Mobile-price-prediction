# %%
import pandas as pd

# Load the dataset
file_path = "C:\\Users\\LENOVO\\Downloads\\mobile phone price prediction (1).csv"
data = pd.read_csv(file_path)

# Display the first few rows of the dataframe
data.head()
# Out:
#    Unnamed: 0                                  Name  Rating  Spec_score  \
# 0           0                 Samsung Galaxy F14 5G    4.65          68
# 1           1                    Samsung Galaxy A11    4.20          63
# 2           2                    Samsung Galaxy A13    4.30          75
# 3           3                    Samsung Galaxy F23    4.10          73
# 4           4  Samsung Galaxy A03s (4GB RAM + 64GB)    4.10          69
#
#                        No_of_sim       Ram            Battery     Display  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE,   4 GB RAM  6000 mAh Battery   6.6 inches
# 1      Dual Sim, 3G, 4G, VoLTE,   2 GB RAM  4000 mAh Battery   6.4 inches
# 2      Dual Sim, 3G, 4G, VoLTE,   4 GB RAM  5000 mAh Battery   6.6 inches
# 3      Dual Sim, 3G, 4G, VoLTE,   4 GB RAM   6000 mAh Battery  6.4 inches
# 4      Dual Sim, 3G, 4G, VoLTE,   4 GB RAM  5000 mAh Battery   6.5 inches
#
#                                               Camera  \
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
# Drop irrelevant columns
data_cleaned = data.drop(columns=['Unnamed: 0', 'Name'])
# Convert Price to numeric (remove commas and convert to integer)
data_cleaned['Price'] = data_cleaned['Price'].str.replace(',', '').astype(int)
data_cleaned['Price']
# Out:
# 0         9999
# 1         9990
# 2        11999
# 3        11999
# 4        11999
#          ...
# 1365     18999
# 1366     24990
# 1367     23990
# 1368     22499
# 1369    119990
# Name: Price, Length: 1370, dtype: int32

# %%
X = data_cleaned.drop(columns=['Price'])
y = data_cleaned['Price']

# %%
# Identify numerical and categorical columns
numerical_cols = X.select_dtypes(include=['int64', 'float64']).columns.tolist()
categorical_cols = X.select_dtypes(include=['object']).columns.tolist()
# numerical_cols
# categorical_cols

# %%
# Preprocessing for numerical data
numerical_transformer = SimpleImputer(strategy='mean')
numerical_transformer
# Preprocessing for categorical data
categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))
])
categorical_transformer
# Out:
# Pipeline(steps=[('imputer', SimpleImputer(strategy='most_frequent')),
#                 ('onehot', OneHotEncoder(handle_unknown='ignore'))])

# %%
# Bundle preprocessing for numerical and categorical data
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numerical_transformer, numerical_cols),
        ('cat', categorical_transformer, categorical_cols)
    ])

# %%
# Define the model
model = RandomForestRegressor(n_estimators=100, random_state=0)

# %%
# Create and evaluate the pipeline
pipeline = Pipeline(steps=[('preprocessor', preprocessor),
                           ('model', model)])

# %%
# Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
# Preprocessing of training data, fit model
pipeline.fit(X_train, y_train)

# Preprocessing of test data, get predictions
y_pred = pipeline.predict(X_test)
y_pred
# Out:
# array([  8077.56      ,  29605.8775    ,  10073.8025    ,  25977.01      ,
#         12302.53      ,  32873.12      ,  49509.645     ,   8585.81      ,
#         20178.35      ,  27381.88      ,  18360.62      ,  15634.92142857,
#         14118.77      ,  15929.3       ,  89722.97      ,  49630.65333333,
#          9591.15083333,  65068.10333333,  46799.02      ,  11794.8525    ,
#         20054.97833333,  49324.2475    ,  43121.19392857,  12334.63      ,
#          7906.44      ,   8127.81      ,  39157.23      ,   8285.86      ,
#         12138.86      ,  26647.47      ,  42927.05666667,  12959.73      ,
#         22826.87      ,  75028.64      ,  58378.24416667,  45881.32666667,
#         18336.40166667,   9088.06      ,   9259.995     ,  25531.63      ,
#          7437.66      ,  25573.14      ,   7973.92      ,  11009.32      ,
#          8065.06      ,  56373.96      ,  53426.44      ,   9578.97416667,
# ...

# %%
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

mae, mse, r2
# Out:
# (5749.718469586374, 98946492.63208294, 0.8614499028669975)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import precision_score, recall_score, classification_report

# %%
# Define price bins
price_bins = [0, 5000, 15000, 30000, float('inf')]
price_labels = ['Low', 'Medium', 'High', 'Premium']

# %%
# Categorize prices into bins
y_binned = pd.cut(y, bins=price_bins, labels=price_labels)

# %%
# Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y_binned, test_size=0.2, random_state=0)

# %%
# Define and train the classification model
clf = Pipeline(steps=[('preprocessor', preprocessor),
                      ('classifier', RandomForestClassifier(n_estimators=100, random_state=0))])

clf.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num', SimpleImputer(),
#                                                   ['Rating', 'Spec_score']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('onehot',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['No_of_sim', 'Ram',
#                                                    'Battery', 'Display',
#                                                    'Camera', 'External_Memory',
#                                                    'Android_version', 'company',
# ...

# %%
# Get predictions
y_pred_class = clf.predict(X_test)
y_pred
# Out:
# array([  8077.56      ,  29605.8775    ,  10073.8025    ,  25977.01      ,
#         12302.53      ,  32873.12      ,  49509.645     ,   8585.81      ,
#         20178.35      ,  27381.88      ,  18360.62      ,  15634.92142857,
#         14118.77      ,  15929.3       ,  89722.97      ,  49630.65333333,
#          9591.15083333,  65068.10333333,  46799.02      ,  11794.8525    ,
#         20054.97833333,  49324.2475    ,  43121.19392857,  12334.63      ,
#          7906.44      ,   8127.81      ,  39157.23      ,   8285.86      ,
#         12138.86      ,  26647.47      ,  42927.05666667,  12959.73      ,
#         22826.87      ,  75028.64      ,  58378.24416667,  45881.32666667,
#         18336.40166667,   9088.06      ,   9259.995     ,  25531.63      ,
#          7437.66      ,  25573.14      ,   7973.92      ,  11009.32      ,
#          8065.06      ,  56373.96      ,  53426.44      ,   9578.97416667,
# ...

# %%
# # Evaluate the classification model
# precision = precision_score(y_test, y_pred_class, average='weighted')
# recall = recall_score(y_test, y_pred_class, average='weighted')
# class_report = classification_report(y_test, y_pred_class)
import pandas as pd

# Define precision, recall, and classification report from the previous output
precision = 0.8198503261375991
recall = 0.8211678832116789
class_report = {
    'High': {'precision': 0.74, 'recall': 0.69, 'f1-score': 0.72, 'support': 85},
    'Medium': {'precision': 0.83, 'recall': 0.90, 'f1-score': 0.86, 'support': 87},
    'Premium': {'precision': 0.88, 'recall': 0.86, 'f1-score': 0.87, 'support': 102},
    'accuracy': {'precision': '', 'recall': '', 'f1-score': 0.82, 'support': 274},
    'macro avg': {'precision': 0.82, 'recall': 0.82, 'f1-score': 0.82, 'support': 274},
    'weighted avg': {'precision': 0.82, 'recall': 0.82, 'f1-score': 0.82, 'support': 274}
}

# Create a DataFrame for the classification report
class_report_df = pd.DataFrame(class_report).T

# Create a DataFrame for precision and recall
metrics_df = pd.DataFrame({
    'Metric': ['Precision', 'Recall'],
    'Value': [precision, recall]
})

# Display the DataFrames
print("Precision and Recall")
print(metrics_df.to_string(index=False))

print("\nClassification Report")
print(class_report_df.to_string())
# Out:
# Precision and Recall
#    Metric    Value
# Precision 0.819850
#    Recall 0.821168
#
# Classification Report
#              precision recall f1-score support
# High              0.74   0.69     0.72    85.0
# Medium            0.83    0.9     0.86    87.0
# Premium           0.88   0.86     0.87   102.0
# accuracy                          0.82     274
# macro avg         0.82   0.82     0.82   274.0
# weighted avg      0.82   0.82     0.82   274.0

# %%
import pickle

# %%
trained_pipeline = pipeline

# %%
# Define the path for the pickle file
pickle_path = "trained_mobile_price_model.pkl"

# %%
# Save the pipeline as a pickle file
with open(pickle_path, 'wb') as file:
    pickle.dump(trained_pipeline, file)

# %%
print(f"Pipeline saved to {pickle_path}")
# Out:
# Pipeline saved to trained_mobile_price_model.pkl

# %%
pip install django
# Out:
# ...
#    ---------------------------------------- 0.0/8.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.2 MB 435.7 kB/s eta 0:00:19
#    ---------------------------------------- 0.0/8.2 MB 393.8 kB/s eta 0:00:21
#    ---------------------------------------- 0.1/8.2 MB 655.4 kB/s eta 0:00:13
#     --------------------------------------- 0.2/8.2 MB 817.0 kB/s eta 0:00:10
#    - -------------------------------------- 0.3/8.2 MB 1.4 MB/s eta 0:00:06
#    -- ------------------------------------- 0.5/8.2 MB 1.8 MB/s eta 0:00:05
#    --- ------------------------------------ 0.8/8.2 MB 2.3 MB/s eta 0:00:04
#    ----- ---------------------------------- 1.1/8.2 MB 2.8 MB/s eta 0:00:03
#    ------ --------------------------------- 1.3/8.2 MB 3.1 MB/s eta 0:00:03
#    ------- -------------------------------- 1.5/8.2 MB 3.3 MB/s eta 0:00:03
#    ------- -------------------------------- 1.6/8.2 MB 3.1 MB/s eta 0:00:03
# ...

# %%
from django.shortcuts import render
from django.http import JsonResponse
from .utils import load_model
def predict_view(request):
    if request.method == 'POST':
        data = request.POST.get('data')  # Assuming you receive data from a POST request
        model = load_model()
        prediction = model.predict([data])
        return JsonResponse({'prediction': prediction.tolist()})
    return render(request, 'predict.html')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[49], line 3
#       1 from django.shortcuts import render
#       2 from django.http import JsonResponse
# ----> 3 from .utils import load_model
#       4 def predict_view(request):
#       5     if request.method == 'POST':
#
# ImportError: attempted relative import with no known parent package
